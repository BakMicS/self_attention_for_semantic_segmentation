# %%
# %run main -model san12 -batch_size 6 -epochs 10 -lr 0.0001 -out_dir san12_84x84_batch_6
# Out:
#   0%|                                                                                                                                                                                                              | 0/244 [00:00<?, ?it/s]
# Epoch 1/10
# ----------
# ...
#   0%|                                                                                                                                                                                                              | 0/242 [00:00<?, ?it/s]
# Train Loss: 1.2825
# ...
#   0%|                                                                                                                                                                                                              | 0/244 [00:00<?, ?it/s]
# Test Loss: 2.1663
# ...

# %%
# %run main -model san19 -batch_size 4 -epochs 10 -lr 0.0001 -out_dir san19_72x72_batch_4
# Out:
#   0%|                                                                                                                                                                                                              | 0/366 [00:00<?, ?it/s]
# Epoch 1/10
# ----------
# ...
#   0%|                                                                                                                                                                                                              | 0/363 [00:00<?, ?it/s]
# Train Loss: 0.7219
# ...
#   0%|                                                                                                                                                                                                              | 0/366 [00:00<?, ?it/s]
# Test Loss: 2.9389
# ...

# %% [markdown]
# #

# %% [markdown]
# #
